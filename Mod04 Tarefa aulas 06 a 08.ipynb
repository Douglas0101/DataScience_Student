# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import numpy as np
import requests

# %%
np.random.seed(42)

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
def get_pvl():
    url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'
    r = requests.get(url)
    return r.json()

df = pd.DataFrame(get_pvl()['items'])
df = df[df['uf'] == 'RJ']
df
# Out:
#       id_pleito tipo_interessado        interessado  cod_ibge  uf  \
# 108       52029        Município     Miguel Pereira   3302908  RJ
# 112       65489        Município        Nova Iguaçu   3303500  RJ
# 124       66729        Município     Miguel Pereira   3302908  RJ
# 226       66609        Município  Casimiro de Abreu   3301306  RJ
# 267       65965        Município        Barra Mansa   3300407  RJ
# ...         ...              ...                ...       ...  ..
# 4457       5645           Estado     Rio de Janeiro        33  RJ
# 4694      34096        Município            Resende   3304201  RJ
# 4718      60057        Município             Paraty   3303807  RJ
# 4751      13669        Município         Petrópolis   3303906  RJ
# 4856      11589        Município            Niterói   3303302  RJ
#
#                    num_pvl                                             status  \
# 108   PVL02.001208/2021-69                                 Arquivado a pedido
# ...

# %%
# 2) Seu código aqui
status = df['status'].value_counts()
columns = ['Solicitações', 'Frequência']
status = status.to_frame().reset_index()
status.columns = columns
status
# Out:
#                                         Solicitações  Frequência
# 0                                           Deferido          23
# 1                                          Arquivado          13
# 2  Encaminhado à PGFN com manifestação técnica fa...          11
# 3                                       Regularizado           8
# 4                     Arquivado por decurso de prazo           7
# 5                                  Deferido (PVL-IF)           5
# 6                                 Arquivado a pedido           3
# 7                    Em retificação pelo interessado           1

# %%
# 3) Seu código aqui
df['ano'] = df['data_status'].str.slice(0, 4)
columns = ['Ano', 'Frequência']
df = df['ano'].value_counts().to_frame().reset_index()
df.columns = columns
df
# Out:
#      Ano  Frequência
# 0   18/0           6
# 1   06/0           5
# 2   04/0           3
# 3   02/0           3
# 4   27/0           3
# 5   29/0           3
# 6   26/0           3
# 7   12/0           3
# 8   28/0           3
# 9   30/1           2
# 10  01/0           2
# 11  11/0           2
# 12  13/0           2
# 13  20/0           2
# 14  21/0           2
# 15  09/0           2
# 16  10/0           2
# 17  18/1           2
# 18  20/1           1
# 19  25/0           1
# 20  04/1           1
# 21  07/1           1
# 22  23/0           1
# 23  30/0           1
# 24  19/1           1
# 25  14/1           1
# 26  23/1           1
# 27  31/1           1
# 28  14/0           1
# 29  17/1           1
# 30  24/0           1
# 31  09/1           1
# 32  31/0           1
# 33  22/0           1
# 34  08/0           1
# 35  06/1           1
# 36  07/0           1
# 37  02/1           1
# 38  17/0           1

# %%
# 4) Seu código aqui
frequencia = df['Ano'].value_counts()
columns = ['Data/Ano', 'Frequência']
frequencia = frequencia.to_frame().reset_index()
frequencia.columns = columns
frequencia
# Out:
#    Data/Ano  Frequência
# 0      18/0           1
# 1      17/1           1
# 2      23/0           1
# 3      30/0           1
# 4      19/1           1
# 5      14/1           1
# 6      23/1           1
# 7      31/1           1
# 8      14/0           1
# 9      24/0           1
# 10     04/1           1
# 11     09/1           1
# 12     31/0           1
# 13     22/0           1
# 14     08/0           1
# 15     06/1           1
# 16     07/0           1
# 17     02/1           1
# 18     07/1           1
# 19     25/0           1
# 20     06/0           1
# 21     30/1           1
# 22     04/0           1
# 23     02/0           1
# 24     27/0           1
# 25     29/0           1
# 26     26/0           1
# 27     12/0           1
# 28     28/0           1
# 29     01/0           1
# 30     20/1           1
# 31     11/0           1
# 32     13/0           1
# 33     20/0           1
# 34     21/0           1
# 35     09/0           1
# 36     10/0           1
# ...

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def get_pvl(uf, interessado):
    url = f'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&interessado={interessado}'
    r = requests.get(url)
    return r.json()

json_data = get_pvl('MG', 'Município')
df = pd.DataFrame(json_data['items'])
df
# Out:
#       id_pleito tipo_interessado                 interessado  cod_ibge  uf  \
# 0         64432        Município                     Formiga   3126109  MG
# 1         59810        Município           Dores de Guanhães   3123106  MG
# 2         60089        Município            Claro dos Poções   3116506  MG
# 3         60836        Município         Conceição dos Ouros   3117801  MG
# 4         65901        Município                  Vespasiano   3171204  MG
# ...         ...              ...                         ...       ...  ..
# 4576      46815        Município               Pingo da Água   3150539  MG
# 4577      42411        Município              Mar de Espanha   3139805  MG
# 4578      45381        Município                   Turmalina   3169703  MG
# 4579      39410        Município  São Sebastião do Rio Verde   3164902  MG
# 4580      41867        Município                     Planura   3151602  MG
#
# ...

# %%
# 2) Seu código aqui
df = df[df['status'] == 'Arquivado por decurso de prazo']
df
# Out:
#       id_pleito tipo_interessado           interessado  cod_ibge  uf  \
# 64        63734        Município               Juatuba   3136652  MG
# 90         9248        Município  Santa Rita do Itueto   3159506  MG
# 97         9847        Município        Frei Inocêncio   3126901  MG
# 138        7241        Município            Cambuquira   3110707  MG
# 217       26878        Município                Muriaé   3143906  MG
# ...         ...              ...                   ...       ...  ..
# 4504       5284        Município                Frutal   3127107  MG
# 4509       5982        Município                Lontra   3138658  MG
# 4524       6991        Município        Fruta de Leite   3127073  MG
# 4534       6686        Município             Veríssimo   3171105  MG
# 4558       8587        Município                Medina   3141405  MG
#
#                    num_pvl                          status  \
# 64    PVL02.000522/2023-96  Arquivado por decurso de prazo
# ...

# %%
# 3) Seu código aqui
def get_pvl(uf):
    url = f'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}'
    r = requests.get(url)
    return r.json()

json_data = get_pvl('BA')
df = pd.DataFrame(json_data['items'])
df
# Out:
#       id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 0         65190        Município           Nordestina   2922656  BA
# 1         48469        Município          Várzea Nova   2933158  BA
# 2         46250        Município               Ibicuí   2912301  BA
# 3         46291        Município               Coribe   2909109  BA
# 4         41070        Município              Lajedão   2918902  BA
# ...         ...              ...                  ...       ...  ..
# 1069       8216        Município           Tapiramutá   2931301  BA
# 1070       4982        Município      Morro do Chapéu   2921708  BA
# 1071      42912        Município     Lauro de Freitas   2919207  BA
# 1072      41509        Município  São Félix do Coribe   2929057  BA
# 1073      42098        Município         Simões Filho   2930709  BA
#
#                    num_pvl                          status  \
# 0     PVL02.002282/2023-64               Deferido (PVL-IF)
# ...

# %%
# 4) Seu código aqui
solicitacoes = df['status'].value_counts()
columns = ['Solicitações', 'Frequência']
solicitacoes = solicitacoes.to_frame().reset_index()
solicitacoes.columns = columns
solicitacoes
# Out:
#                                          Solicitações  Frequência
# 0                                            Deferido         494
# 1                                   Deferido (PVL-IF)         174
# 2                      Arquivado por decurso de prazo         136
# 3                                           Arquivado         108
# 4   Encaminhado à PGFN com manifestação técnica fa...          61
# 5                                        Regularizado          35
# 6                                  Arquivado a pedido          23
# 7                     Em retificação pelo interessado          12
# 8                                          Indeferido          10
# 9                           Pendente de regularização           8
# 10                         Em retificação pelo credor           4
# 11                Em retificação pelo credor (PVL-IF)           2
# 12                                 Arquivado pela STN           2
# ...

# %%
# 4) Seu código aqui
df.to_csv('pvl_bahia.csv', index=False, sep=';', encoding='utf-8')

# %%
df.to_excel('pvl_bahia.xlsx', index=False, sheet_name='pvl_bahia', startrow=0, startcol=0)
